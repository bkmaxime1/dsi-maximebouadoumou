# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
# !pwd
# Out:
# /Users/maximeb/Documents/dsi-maximebouadoumou/week-02/5.2-lab/code/starter-code

# %%
# Read in billboard.csv as a data frame
df5 = pd.read_csv("../../assets/datasets/billboard.csv")
#df1 .index=df1['track']

# %%
#find the duplicated track and the artist name
df5[df5['track']=='Where I Wanna Be']
# Out:
#      year artist.inverted             track  time genre date.entered  \
# 118  2000   Jones, Donell  Where I Wanna Be  6:22  Rock   2000-04-22
# 305  2000   Sheist, Shade  Where I Wanna Be  4:16   Rap   2000-11-11
#
#     date.peaked  x1st.week  x2nd.week  x3rd.week     ...      x67th.week  \
# 118  2000-07-08         81       71.0       65.0     ...             NaN
# 305  2000-11-18         96       95.0       99.0     ...             NaN
#
#      x68th.week  x69th.week  x70th.week  x71st.week  x72nd.week  x73rd.week  \
# 118         NaN         NaN         NaN         NaN         NaN         NaN
# 305         NaN         NaN         NaN         NaN         NaN         NaN
#
#      x74th.week  x75th.week  x76th.week
# 118         NaN         NaN         NaN
# 305         NaN         NaN         NaN
#
# [2 rows x 83 columns]

# %%
# Changing artist header to be shorter -- artist
df5.rename(columns={"artist.inverted": "artist"}, )
# Out:
#      year               artist  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
#check for the duplicated track
pd.value_counts(df1["track"])
# Out:
# Where I Wanna Be                       2
# If You Don't Wanna Love Me             1
# Just Be A Man About It                 1
# With Arms Wide Open                    1
# Girls Dem Sugar                        1
# More                                   1
# Rhythm Divine                          1
# Case Of The Ex (Whatcha Gonna Do)      1
# Pull Over                              1
# Without You                            1
# We Danced                              1
# 911                                    1
# Left, Right, Left                      1
# N 2 Gether Now                         1
# I Lost It                              1
# Otherside                              1
# A Country Boy Can Survive              1
# Rollin'                                1
# Shackles (Praise You)                  1
# American Pie                           1
# I Think I'm In Love With You           1
# Feelin' Good                           1
# What You Want                          1
# ...

# %%
df1.duplicated['track']
# Out:
#                                                     year      artist.inverted  \
# track
# Independent Women Part I                            2000      Destiny's Child
# Maria, Maria                                        2000              Santana
# I Knew I Loved You                                  2000        Savage Garden
# Music                                               2000              Madonna
# Come On Over Baby (All I Want Is You)               2000  Aguilera, Christina
# Doesn't Really Matter                               2000                Janet
# Say My Name                                         2000      Destiny's Child
# Be With You                                         2000    Iglesias, Enrique
# Incomplete                                          2000                Sisqo
# Amazed                                              2000             Lonestar
# It's Gonna Be Me                                    2000               N'Sync
# ...

# %%
df1.ix[:,7:].notnull().sum(axis=1)
# Out:
# track
# Independent Women Part I                                        28
# Maria, Maria                                                    26
# I Knew I Loved You                                              33
# Music                                                           24
# Come On Over Baby (All I Want Is You)                           21
# Doesn't Really Matter                                           24
# Say My Name                                                     32
# Be With You                                                     20
# Incomplete                                                      26
# Amazed                                                          55
# It's Gonna Be Me                                                25
# What A Girl Wants                                               24
# Everything You Want                                             41
# With Arms Wide Open                                             47
# ...

# %%
df.dtypes
# Out:
# year                 int64
# artist.inverted     object
# track               object
# time                object
# genre               object
# date.entered        object
# date.peaked         object
# x1st.week            int64
# x2nd.week          float64
# x3rd.week          float64
# x4th.week          float64
# x5th.week          float64
# x6th.week          float64
# x7th.week          float64
# x8th.week          float64
# x9th.week          float64
# x10th.week         float64
# x11th.week         float64
# x12th.week         float64
# x13th.week         float64
# x14th.week         float64
# x15th.week         float64
# x16th.week         float64
# x17th.week         float64
# x18th.week         float64
# x19th.week         float64
# x20th.week         float64
# x21st.week         float64
# x22nd.week         float64
# x23rd.week         float64
#                     ...
# x47th.week         float64
# x48th.week         float64
# x49th.week         float64
# ...

# %%
# The simplest pivot table must have a dataframe and an 
# index. Let’s use the artist as our index.
pd.pivot_table(df,index=["artist.inverted","track"])
# Out:
#                                                                          x10th.week  \
# artist.inverted      track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                        NaN
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...         NaN
# 3 Doors Down         Kryptonite                                                51.0
#                      Loser                                                     61.0
# 504 Boyz             Wobble Wobble                                             57.0
# 98�                  Give Me Just One Night (Una Noche)                         6.0
# A*Teens              Dancing Queen                                              NaN
# Aaliyah              I Don't Wanna                                             36.0
#                      Try Again                                                 10.0
# Adams, Yolanda       Open My Heart                                             59.0
# ...

# %%
# Let's look at the data by artist and track. 
pd.pivot_table(df,index=["artist.inverted","track"])
# Out:
#                                                                          x10th.week  \
# artist.inverted      track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                        NaN
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...         NaN
# 3 Doors Down         Kryptonite                                                51.0
#                      Loser                                                     61.0
# 504 Boyz             Wobble Wobble                                             57.0
# 98�                  Give Me Just One Night (Una Noche)                         6.0
# A*Teens              Dancing Queen                                              NaN
# Aaliyah              I Don't Wanna                                             36.0
#                      Try Again                                                 10.0
# Adams, Yolanda       Open My Heart                                             59.0
# ...

# %%
#pd.pivot_table(df,index=["artist.inverted","track"],values=["x10th.week":"x9th.week"],aggfunc="count")
df2 = pd.melt(df1,id_vars=["artist.inverted","track"], value_vars=list(df.iloc[:, 7:]))#make horizontal data to vertical
df2
# Out:
#            artist.inverted                                              track  \
# 0          Destiny's Child                           Independent Women Part I
# 1                  Santana                                       Maria, Maria
# 2            Savage Garden                                 I Knew I Loved You
# 3                  Madonna                                              Music
# 4      Aguilera, Christina              Come On Over Baby (All I Want Is You)
# 5                    Janet                              Doesn't Really Matter
# 6          Destiny's Child                                        Say My Name
# 7        Iglesias, Enrique                                        Be With You
# 8                    Sisqo                                         Incomplete
# 9                 Lonestar                                             Amazed
# 10                  N'Sync                                   It's Gonna Be Me
# ...

# %%
#combine artist name and track for the two artists and tracks to be 2 different index
df4=pd.pivot_table(df2, index=["artist.inverted","track"],aggfunc ="count")
df4
df4.shape
# Out:
# (317, 2)

# %%
# find out the number of weeks each song has been on the billboard
df['date.entered']=pd.to_datetime(df['date.entered'])

# %%
df['date.peaked']=pd.to_datetime(df['date.peaked'])

# %%
df['date.peaked']
# Out:
# 0     2000-11-18
# 1     2000-04-08
# 2     2000-01-29
# 3     2000-09-16
# 4     2000-10-14
# 5     2000-08-26
# 6     2000-03-18
# 7     2000-06-24
# 8     2000-08-12
# 9     2000-03-04
# 10    2000-07-29
# 11    2000-01-15
# 12    2000-07-15
# 13    2000-11-11
# 14    2000-06-17
# 15    2000-07-22
# 16    2000-02-19
# 17    2000-04-22
# 18    2000-12-02
# 19    2000-12-30
# 20    2000-05-06
# 21    2000-06-03
# 22    2000-09-30
# 23    2000-08-19
# 24    2000-11-11
# 25    2000-05-20
# 26    2000-07-01
# 27    2000-01-08
# 28    2000-07-01
# 29    2000-02-12
#          ...
# 287   2000-09-09
# 288   2000-09-16
# 289   2000-07-22
# 290   2000-02-05
# 291   2000-03-11
# 292   2000-06-17
# 293   2000-04-15
# 294   2000-08-26
# 295   2000-01-15
# 296   2000-01-22
# 297   2000-12-02
# 298   2000-05-20
# 299   2000-06-17
# 300   2000-05-06
# 301   2000-04-01
# 302   2000-09-16
# 303   2000-09-16
# 304   2000-07-29
# 305   2000-11-18
# 306   2000-12-23
# 307   2000-03-11
# ...

# %%
df['days_to_peak']=df['date.peaked']-df['date.entered']
df
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
df4
# Out:
#                                                                          value  \
# artist.inverted      track
# 2 Pac                Baby Don't Cry (Keep Ya Head Up II)                     7
# 2Ge+her              The Hardest Part Of Breaking Up (Is Getting Bac...      3
# 3 Doors Down         Kryptonite                                             53
#                      Loser                                                  20
# 504 Boyz             Wobble Wobble                                          18
# 98�                  Give Me Just One Night (Una Noche)                     20
# A*Teens              Dancing Queen                                           5
# Aaliyah              I Don't Wanna                                          20
#                      Try Again                                              32
# Adams, Yolanda       Open My Heart                                          20
# ...

# %%
df1.shape
# Out:
# (317, 83)

# %%
df4.shape
# Out:
# (316, 3)

# %%
df4.columns
# Out:
# Index([u'artist.inverted', u'value', u'variable'], dtype='object')

# %%
# add this as a new column
# inner join
# inner join
pd.merge(df5, df4, on='track', how='inner')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-98-16b1143c1e93> in <module>()
#       2 # inner join
#       3 # inner join
# ----> 4 pd.merge(df5, df4, on='track', how='inner')
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator)
#      36                          right_on=right_on, left_index=left_index,
#      37                          right_index=right_index, sort=sort, suffixes=suffixes,
# ---> 38                          copy=copy, indicator=indicator)
#      39     return op.get_result()
#      40 if __debug__:
#
# //anaconda/lib/python2.7/site-packages/pandas/tools/merge.pyc in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator)
# ...

# %%
del df1['weeks_on_track']
df1
# Out:
#      year      artist.inverted  \
# 0    2000      Destiny's Child
# 1    2000              Santana
# 2    2000        Savage Garden
# 3    2000              Madonna
# 4    2000  Aguilera, Christina
# 5    2000                Janet
# 6    2000      Destiny's Child
# 7    2000    Iglesias, Enrique
# 8    2000                Sisqo
# 9    2000             Lonestar
# 10   2000               N'Sync
# 11   2000  Aguilera, Christina
# 12   2000     Vertical Horizon
# 13   2000                Creed
# 14   2000              Aaliyah
# 15   2000      matchbox twenty
# 16   2000        Carey, Mariah
# 17   2000          Hill, Faith
# 18   2000                  Mya
# 19   2000                Dream
# 20   2000        Braxton, Toni
# 21   2000        Anthony, Marc
# 22   2000                  98�
# 23   2000      Destiny's Child
# 24   2000         3 Doors Down
# 25   2000                Sisqo
# 26   2000  Aguilera, Christina
# 27   2000     Houston, Whitney
# 28   2000                  Joe
# ...

# %%
df1
# Out:
#                                                     year      artist.inverted  \
# track
# Independent Women Part I                            2000      Destiny's Child
# Maria, Maria                                        2000              Santana
# I Knew I Loved You                                  2000        Savage Garden
# Music                                               2000              Madonna
# Come On Over Baby (All I Want Is You)               2000  Aguilera, Christina
# Doesn't Really Matter                               2000                Janet
# Say My Name                                         2000      Destiny's Child
# Be With You                                         2000    Iglesias, Enrique
# Incomplete                                          2000                Sisqo
# Amazed                                              2000             Lonestar
# It's Gonna Be Me                                    2000               N'Sync
# ...

# %%
# make a new df with just weeks on billboard, artist, and track
