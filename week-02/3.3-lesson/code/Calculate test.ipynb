# %%
import numpy as np
import scipy as sp
import pandas as pd
from scipy import stats
import seaborn as sns
# %matplotlib inline

# %%
one_sample_data=[177.3,182.7,169.6,176.3,180.3,179.4,178.5,177.2,181.8,176.5]
np.mean(one_sample_data)
# Out:
# 177.96000000000001

# %%
one_sample = stats.ttest_1samp(one_sample_data,175.3)
print "Mean: {}\nStd: {}".format(np.mean(one_sample_data),np.std(one_sample_data))
print "The t-statistic is %.3f and the p-value is %.3f." %one_sample
# Out:
# Mean: 177.96
# Std: 3.47626236064
# The t-statistic is 2.296 and the p-value is 0.047.

# %%
sns.distplot(one_sample_data,bins=10)

# %%
two_sample_data=[189.3,200.5,179.7,199.1,178.4,197.9,202.3,178.3,178.9,209.2]

# %%
sns.distplot(two_sample_data, bins=10,color ='green')

# %%
two_sample = stats.ttest_ind(one_sample_data,two_sample_data)
print "The t-statistic is %.3f and the p-value is %.3f." %two_sample
print "Mean: {}\nStd: {}".format(np.mean(two_sample_data),np.std(two_sample_data))
# Out:
# The t-statistic is -3.423 and the p-value is 0.003.
# Mean: 191.36
# Std: 11.2167018325

# %%
sns.distplot(two_sample_data,hist=False, color ='green')
sns.distplot(one_sample_data,hist=False, color ='green')

# %%
two_sample = stats.ttest_ind(two_sample_data,one_sample_data)
print "The t-statistic is %.3f and the p-value is %.3f." %two_sample
# Out:
# The t-statistic is 3.423 and the p-value is 0.003.

# %%
two_sample = stats.ttest_rel(one_sample_data,two_sample_data)
print "The t-statistic is %.3f and the p-value is %.3f." %two_sample
print "Mean: {}\nStd: {}".format(np.mean(two_sample_data),np.std(two_sample_data))
# Out:
# The t-statistic is -3.556 and the p-value is 0.006.
# Mean: 191.36
# Std: 11.2167018325
